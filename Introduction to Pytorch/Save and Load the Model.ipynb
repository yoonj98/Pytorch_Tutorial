# %% [markdown]
# ## Pytorch Tutorials : Save and Load the Model
# - [Pytorch Tutorials](https://pytorch.org/tutorials/)
# - [Save and Load the Model](https://pytorch.org/tutorials/beginner/basics/saveloadrun_tutorial.html)

# %%
import torch
import torch.onnx as onnx
import torchvision.models as models

# %% [markdown]
# ### Saving and Loading Model Weights
# `state_dict` : PyTorch 모델은 학습된 매개변수를 이라는 내부 상태 사전에 저장

# %%
model = models.vgg16(pretrained=True)
torch.save(model.state_dict(), 'model_weights.pth')

# %% [markdown]
# 모델 가중치를 로드하려면 먼저 동일한 모델의 인스턴스를 생성한 다음 `load_state_dict()`를 사용하여 매개변수를 로드해야 합니다.

# %%
model = models.vgg16() 
model.load_state_dict(torch.load('model_weights.pth'))
model.eval()

# %% [markdown]
# ### Saving and Loading Models with Shapes
# 모델 가중치를 로드할 때, 클래스가 네트워크의 구조를 정의하기 때문에 모델 클래스를 먼저 인스턴스화해야 한다.

# %%
torch.save(model, 'model.pth')

# %%
model = torch.load('model.pth')
